# %%
import pandas as pd
import numpy as np
traffic_data = pd.read_csv("TDCS_M06A_20190830_080000.csv", header=None)

# %%
traffic_data
# Out:
#          0                    1         2                    3         4  \
# 0       31  2019-08-30 08:17:14  03F3307N  2019-08-30 08:17:14  03F3307N
# 1       31  2019-08-30 08:01:02  03F0648S  2019-08-30 08:01:02  03F0648S
# 2       31  2019-08-30 08:51:45  03F0648N  2019-08-30 08:57:09  03F0559N
# 3       31  2019-08-30 08:20:45  03F3854S  2019-08-30 08:20:45  03F3854S
# 4       32  2019-08-30 08:06:10  03F4168S  2019-08-30 08:09:33  03F4232S
# ...     ..                  ...       ...                  ...       ...
# 259618  31  2019-08-30 08:50:21  01F0376N  2019-08-30 08:53:05  01F0339N
# 259619  31  2019-08-30 08:07:35  01F0248S  2019-08-30 08:34:23  01F0681S
# 259620  31  2019-08-30 08:19:05  05F0309N  2019-08-30 08:19:05  05F0309N
# 259621  31  2019-08-30 08:38:11  05F0055N  2019-08-30 08:38:11  05F0055N
# 259622  32  2019-08-30 08:42:35  03F0150N  2019-08-30 08:42:35  03F0150N
#
#            5  6                                                  7
# ...

# %%
start_time = traffic_data[1]

# %%
start_time
# Out:
# 0         2019-08-30 08:17:14
# 1         2019-08-30 08:01:02
# 2         2019-08-30 08:51:45
# 3         2019-08-30 08:20:45
# 4         2019-08-30 08:06:10
#                  ...
# 259618    2019-08-30 08:50:21
# 259619    2019-08-30 08:07:35
# 259620    2019-08-30 08:19:05
# 259621    2019-08-30 08:38:11
# 259622    2019-08-30 08:42:35
# Name: 1, Length: 259623, dtype: object

# %%
sorted_start = sorted(start_time)
sorted_start
# Out:
# ['2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
# ...

# %%
end_time = traffic_data[3]

# %%
end_time
# Out:
# 0         2019-08-30 08:17:14
# 1         2019-08-30 08:01:02
# 2         2019-08-30 08:57:09
# 3         2019-08-30 08:20:45
# 4         2019-08-30 08:09:33
#                  ...
# 259618    2019-08-30 08:53:05
# 259619    2019-08-30 08:34:23
# 259620    2019-08-30 08:19:05
# 259621    2019-08-30 08:38:11
# 259622    2019-08-30 08:42:35
# Name: 3, Length: 259623, dtype: object

# %%
sorted_end = sorted(end_time)
sorted_end
# Out:
# ['2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:00',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
#  '2019-08-30 08:00:01',
# ...

# %%
import time

start_time_temp = []    
for i in range(259622):   
    st = time.strptime(start_time[i], "%Y-%m-%d %H:%M:%S") 
    st_temp = st.tm_min *100 + st.tm_sec
   
    start_time_temp.append(st_temp)
    
start_time_temp
# Out:
# [1714,
#  102,
#  5145,
#  2045,
#  610,
#  5235,
#  5044,
#  916,
#  1847,
#  3045,
#  3312,
#  2551,
#  4503,
#  2107,
#  3754,
#  1649,
#  4748,
#  4951,
#  5022,
#  5318,
#  3514,
#  3118,
#  2617,
#  3509,
#  4720,
#  3546,
#  4655,
#  412,
#  715,
#  2322,
#  2617,
#  5526,
#  3654,
#  5502,
#  3342,
#  4449,
#  2241,
#  57,
#  2749,
#  946,
#  2808,
#  134,
#  5657,
#  5737,
#  4234,
#  2341,
#  404,
#  721,
#  1018,
#  1150,
#  5123,
#  3219,
#  1929,
#  2115,
#  4612,
#  735,
#  3942,
#  5128,
#  5048,
#  2347,
#  4759,
#  1006,
#  2116,
#  1408,
#  4827,
#  4342,
#  1057,
#  407,
#  4900,
#  4125,
#  5040,
#  5434,
#  1043,
#  2510,
#  4109,
#  2846,
#  4437,
#  4358,
#  3053,
#  4844,
#  830,
#  5723,
#  4358,
#  1030,
#  2736,
#  126,
#  5913,
#  3501,
#  4313,
#  4815,
#  2924,
#  5905,
#  1305,
#  4010,
#  5233,
#  2239,
#  4246,
#  2947,
#  1440,
#  304,
#  4734,
#  716,
#  2540,
#  406,
#  4712,
#  948,
#  2326,
#  2307,
#  4057,
#  5915,
#  5015,
#  5706,
#  352,
# ...

# %%
import matplotlib.pyplot as plt


X=[0,0,0,0,0,0]
for i in start_time_temp:
    if i <1000:
        X[0] = X[0]+1
    elif i < 2000:
        X[1] = X[1]+1
    elif i < 3000:
        X[2] = X[2]+1
    elif i < 4000:
        X[3] = X[3]+1
    elif i < 5000:
        X[4] = X[4]+1
    else:
        X[5] = X[5]+1

labels=['8:00-8:10','8:10-8:20','8:20-8:30','8:30-8:40','8:40-8:50','8:50-9:00'] 

fig = plt.figure(figsize=(5,5))
plt.pie(X,labels=labels,radius=1,wedgeprops=dict(width=1,edgecolor="w")) 
plt.title("distribution of the start time")
# Out:
# Text(0.5, 1.0, 'distribution of the start time')

# %%
end_time_temp = []    
for i in range(259622):   
    ed = time.strptime(end_time[i], "%Y-%m-%d %H:%M:%S") 
    ed_temp = ed.tm_min *100 + ed.tm_sec
   
    end_time_temp.append(ed_temp)
    
end_time_temp
# Out:
# [1714,
#  102,
#  5709,
#  2045,
#  933,
#  5814,
#  5154,
#  916,
#  1847,
#  3424,
#  5354,
#  3043,
#  2012,
#  2107,
#  4131,
#  2305,
#  304,
#  5641,
#  5022,
#  5455,
#  3514,
#  1210,
#  722,
#  207,
#  314,
#  2716,
#  731,
#  637,
#  1034,
#  2322,
#  2617,
#  2910,
#  5954,
#  5816,
#  3342,
#  4449,
#  5101,
#  57,
#  2749,
#  1939,
#  2808,
#  828,
#  936,
#  1342,
#  4708,
#  2614,
#  4212,
#  1725,
#  1346,
#  1458,
#  3854,
#  3419,
#  3925,
#  2115,
#  4612,
#  735,
#  814,
#  5537,
#  222,
#  3438,
#  4759,
#  1006,
#  5847,
#  1408,
#  514,
#  5040,
#  1057,
#  407,
#  5211,
#  4125,
#  3701,
#  2240,
#  1043,
#  2817,
#  5923,
#  3736,
#  2214,
#  45,
#  4051,
#  920,
#  830,
#  5723,
#  4358,
#  1030,
#  3932,
#  2833,
#  2015,
#  3501,
#  4313,
#  4940,
#  3108,
#  5905,
#  1601,
#  4010,
#  5233,
#  2239,
#  4246,
#  4855,
#  2713,
#  304,
#  5644,
#  716,
#  5912,
#  3840,
#  5231,
#  948,
#  2326,
#  3444,
#  4659,
#  1318,
#  3811,
#  102,
#  5248,
#  5056,
# ...

# %%
import matplotlib.pyplot as plt


X2=[0,0,0,0,0,0]
for i in end_time_temp:
    if i <1000:
        X2[0] = X2[0]+1
    elif i < 2000:
        X2[1] = X2[1]+1
    elif i < 3000:
        X2[2] = X2[2]+1
    elif i < 4000:
        X2[3] = X2[3]+1
    elif i < 5000:
        X2[4] = X2[4]+1
    else:
        X2[5] = X2[5]+1

labels=['8:00-8:10','8:10-8:20','8:20-8:30','8:30-8:40','8:40-8:50','8:50-9:00'] 

fig = plt.figure(figsize=(5,5))
plt.pie(X2,labels=labels,radius=1,wedgeprops=dict(width=1,edgecolor="w")) 
plt.title("distribution of the end time")
# Out:
# Text(0.5, 1.0, 'distribution of the end time')

# %%
duration_time = np.array(end_time_temp)-np.array(start_time_temp)

# %%
duration_time
# Out:
# array([   0,    0,  564, ..., 2688,    0,    0])

# %%
if (end_time_temp==start_time_temp):
    print ("1")

# %%
max(duration_time)
# Out:
# 5927

# %%
import matplotlib.pyplot as plt


X3=[0,0,0,0,0,0]
for i in duration_time:
    if i <1000:
        X3[0] = X3[0]+1
    elif i < 2000:
        X3[1] = X3[1]+1
    elif i < 3000:
        X3[2] = X3[2]+1
    elif i < 4000:
        X3[3] = X3[3]+1
    elif i < 5000:
        X3[4] = X3[4]+1
    else:
        X3[5] = X3[5]+1

labels=['0-10min','10-20min','20-30min','30-40min','40-50min','50-60min'] 

fig = plt.figure(figsize=(5,5))
plt.pie(X2,labels=labels,radius=1,wedgeprops=dict(width=1,edgecolor="w")) 
plt.title("distribution of the duration time")
# Out:
# Text(0.5, 1.0, 'distribution of the duration time')
